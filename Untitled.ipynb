# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import matplotlib.pyplot as plt

# %%
wc = WordCloud(background_color="white",width=2000,height=1500, max_words=50,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(dictionary)
plt.figure(figsize=(16,9))
plt.imshow(wc)

# %%
import matplotlib.pyplot as plt

D = dict(Counter(filtered_text).most_common(50))
plt.figure(figsize=(25,10))
plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
plt.xticks(rotation=45)
plt.xlabel('Words')
plt.title('Words frequency')
plt.ylabel('frequency')
plt.show()

# %%
from collections import Counter

# %%
text="hello there is is is my nazme is Vaibhav"
dictionary= dict(Counter(filtered_text).most_common(100))

# %%
Counter(text.split()).most_common(2)

# %%
# import libraries
import os
import re
from config import Config
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
import datetime
from datetime import date
from wordcloud import WordCloud, STOPWORDS
from collections import Counter

# Define exogenous variables
input_folder_path = 'assignment_2_files/letters/'
add_input_path = 'additional_input/cik_ticker.csv'
output_folder_path = 'results/'

# Configure the programme
Config.dir_create(output_folder_path)
register_matplotlib_converters()

# %%
from analysis import Solve

# %%
obj = Solve(input_folder_path, add_input_path, output_folder_path)
obj.exec()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-55915c20c7f8> in <module>
#       1 obj = Solve(input_folder_path, add_input_path, output_folder_path)
# ----> 2 obj.exec()
#
# ~/Desktop/AM16_SPR20_Financial_Reporting_Analytics/Assignment 2/analysis.py in exec(self)
#     120         def exec(self):
#     121                 self.read_files()
# --> 122                 self.text_analytics()
#     123                 self.overview()
#     124                 self.ticker_add()
#
# ~/Desktop/AM16_SPR20_Financial_Reporting_Analytics/Assignment 2/analysis.py in text_analytics(self)
#      55                 plt.figure(figsize = (16, 9))
#      56                 self.wc = WordCloud(background_color="white",width=2000,height=1500, max_words=10,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(self.wordcloud_input)
# ...

# %%
plt.figure(figsize=(16,9))
plt.imshow(obj.wc)

# %%
obj.files_concat
# Out:
# ' MAY 11 2'

# %%
# !pip3 install nltk

# %%
import nltk
from nltk.corpus import stopwords
set1=set(stopwords.words('english'))#+['31', 'comments', 'company', 'please', 'form', 'page', 'disclosure', 'financial', 'inc.', 'year', 'ended', 'mr.', 'also', 'no.', '2', 'accounting', 'note', 'may', 'us', 'staff', 'december', 'response', 'related', 'aircraft'])

# %%
filtered_text=[i for i in obj.files_concat.split() if i.lower() not in set1]
filtered_text[:10]
# Out:
# ['MAY',
#  '11',
#  '2012',
#  'VIA',
#  'E-MAIL',
#  'ZANE',
#  'C.',
#  'ROWE',
#  'EXECUTIVE',
#  'VICE']
